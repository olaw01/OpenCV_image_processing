# %% [markdown]
# <a href="https://colab.research.google.com/github/olaw01/OpenCV_image_processing/blob/main/04_optical-character-recognition/ocr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Pytesseract

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.
# ...

# %%
import pytesseract
from PIL import Image
import imutils
import cv2
from google.colab import files

uploaded = files.upload()

# %%
text = pytesseract.image_to_string(Image.open('cap_1.jfif'))
print(text)
